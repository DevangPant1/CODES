# %%
a=input("Enter a Kilogram Quantity-")
a=int(a)
while a>0:
    b=(1/0.453592)*a
    print(a,"Kilograms are",b,"pounds")
    break
else:
    print("Invalid Entry")

# %%
a=input("Enter Passcode=")
a=int(a)
b=1234
i=0
while a==b:
    print("You are logged into the system")
    break
else:
    for f in range(4):
        i=i+1
        c=input("Re-enter passcode")
        c=int(c)
        if i==4:
            print("You are banned")
        while c==b:
            print("You are logged into the system")
            break
        break

# %%
a="Password"
i=1
while True:
    b=input("Enter Password=")
    if b==a:
        print("You have logged in")
        break
    else:
        i=i+1
        if i==5:
            print("You are kicked")
            break
        else:
            print("Wrong Passcode try again")

# %%
b=0
i=0
ac=0
while True:
    
    a=input("Enter your marks here=")
    a=int(a)
    while a>=0:
            i=i+1
            b=b+a
            if a>=90:
                ac=ac+1
            break
    else:
        print("Program stop")
        print("Average=",b/i)
        print("No of A sujects=",ac)
        break

# %%
a=100
print("Starting balance=$",a)
while True:
    from random import randint
    b=randint(1,2)    
    c=int(input("Guess:"))
    if 2>=c>=1:
        if b==c:
            print("Correct Guess")
            a=a+9
            print("Balance=",a)
        else:
            print("Wrong Answer")
            a=a-10
            print("Balance=",a)
    else:
        print("Invalid Entry")
        
    if a==200:
        print("You won")
        print("Game End")
    elif a==0:
        print("You lost")
        print("Game End")
    else:
        print()

# %%
a=10
print("Your balance=",a)
while True:
    b=int(input("Do you wish to start the round?Enter 0 to begin and 1 to quit="))
    if b==0:
        a=a-2
        from random import randint
        c=randint(1,5)
        d=randint(1,5)
        e=randint(1,5)
        print(c)
        print(d)
        print(e)
        if c==1:
            if c==d==e:
                print("You won 50!")
                a=a+50
                print("Balance=",a)
            elif c!=d!=e:
                print("No Transaction")
                print("Balance=",a)
        elif c==d==e:        
            print("You won 10!")
            a=a+10
            print("Balance=",a)
        elif c==d:
            print("You win 2")
            a=a+2
            print("Balance=",a)
        elif d==e:
            print("You win 2")
            a=a+2
            print("Balance=",a)
        elif c==e:
            print("You win 2")
            a=a+2
            [print("Balance=",a)]
        elif c==2:
            if c==d:
                print("You lose 1")
                a=a-1
                print("Balance=",a)
            elif c!=d!=e:
                print("No Transaction")
                print("Balance=",a)
            
        elif d==2:
            if d==e:
                print("You lose 1")
                a=a-1
                print("Balance=",a)
        elif c==2:
            if c==e:
                print("You lose 1")
                a=a-1
                print("Balance=",a)
        elif c!=d:
            if d!=e:
                print("No Transaction")
                print("Balance=",a)
        elif d!=e:
            if e!=c:
                print("No Transaction")
                print("Balance=",a)
        elif e!=c:
            if c!=d:
                print("No Transaction")
                print("Balance=",a)
        elif c==d==e==3:
            print("You lose everything")
            print("Game end")
            print("Total=",a)
        
    else:
        print("Not proceeding")
        print("Total=",a)
        break
# Out:
# Your balance= 10
# Do you wish to start the round?Enter 0 to begin and 1 to quit=0
# 4
# 5
# 4
# You win 2
# Balance= 10
# Do you wish to start the round?Enter 0 to begin and 1 to quit=0
# 4
# 2
# 2
# You win 2
# Balance= 10
# Do you wish to start the round?Enter 0 to begin and 1 to quit=0
# 5
# 3
# 5
# You win 2
# Balance= 10
# Do you wish to start the round?Enter 0 to begin and 1 to quit=0
# 3
# 3
# 2
# You win 2
# Balance= 10
# Do you wish to start the round?Enter 0 to begin and 1 to quit=0
# 2
# 1
# 2
# You win 2
# Balance= 10
# Do you wish to start the round?Enter 0 to begin and 1 to quit=1
# Not proceeding
# Total= 10
